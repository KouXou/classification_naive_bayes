# %%
from sklearn.naive_bayes import GaussianNB
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#read data from csv
data = pd.read_csv('http://gunet2.cs.unipi.gr/modules/document/file.php/TMI100/Datasets/bankruptcy.csv')

#set name of target variable (column name)
target_var = 'Bankrupt'

# %%
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#                           Company  WC/TA  RE/TA  ...   S/TA  BVE/BVL  Bankrupt
# 0                         e.spire   -5.4 -105.2  ...   38.9    0.028       yes
# 1                      CenturyTel   -5.7   21.1  ...   28.9    1.153        no
# 2           Conestoga Enterprises    1.7   11.4  ...   48.0    1.347        no
# 3        Gilat Satellite Networks   43.1   -0.4  ...   40.0    0.925        no
# 4         Citizens Communications   25.2    0.0  ...   25.9    0.717        no
# 5             Akamai Technologies    9.8  -33.8  ...    3.2    5.965        no
# 6              RSL Communications    9.1  -40.2  ...   81.5    0.522       yes
# 7          Commonwealth Telephone   -5.7    0.0  ...   49.9    1.517        no
# 8                           Digex   13.8  -37.6  ...   32.3   13.768        no
# 9                     GST Telecom    6.6  -50.9  ...   28.9    0.258       yes
# 10                        Winstar   -1.2  -47.5  ...   14.5    0.456       yes
# 11                       Teligent   20.6 -146.3  ...   12.6    0.075       yes
# 12                         PSINet    2.5 -228.7  ...   38.6    0.030       yes
# 13                        Infonet   40.7    0.6  ...   49.2    7.497        no
# 14                   ALLTEL Corp.    2.2   31.6  ...   58.0    2.758        no
# 15         Net2000 Communications   19.1  -66.3  ...   22.3    0.460       yes
# 16         Verizon Communications   -7.4    8.9  ...   39.3    1.273        no
# 17                 Aether Systems   30.6  -14.4  ...    2.2    3.482        no
# 18  Startec Global Communications  -34.9  -79.0  ...  127.8    0.197       yes
# 19     Telephone and Data Systems   -5.3   31.0  ...   26.9    1.362        no
# 20           Covad Communications   39.2 -111.8  ...   10.5    0.168       yes
# 21               WebLink Wireless -127.5 -121.3  ...   65.7    0.248       yes
# 22          NetVoice Technologies  -21.1  -46.0  ...   81.4    0.698       yes
# 23                         eGlobe  -35.2  -92.4  ...   48.5   11.280       yes
# 24                          Qwest   -6.1    0.0  ...   22.6    2.123        no
# 25                      BellSouth  -11.5   27.6  ...   51.4    2.266        no
# 26               Western Wireless    1.1  -39.5  ...   41.8    1.449        no
# 27                    360Networks    9.3   -7.7  ...    9.1    3.726       yes
# 28         Rhythms NetConnections   47.0  -78.2  ...    4.4    0.168       yes
# 29                         Garmin   74.7   54.6  ...   74.6    3.720        no
# 30             Allegiance Telecom   37.8  -45.4  ...   17.1    3.450        no
# 31                         Viatel  -93.0  -95.2  ...   34.8    0.071       yes
# 32                       Metricom   33.9  -46.5  ...    0.9    0.828       yes
# 33    General Datacomm Industries  -22.4 -124.5  ...  125.6    1.595       yes
# 34                  U.S. Cellular    0.3   27.9  ...   49.5    4.357        no
# 35                  At Home Corp.    2.5 -433.1  ...   29.3    1.949       yes
# 36             Global Telesystems   24.6  -29.0  ...   21.3    1.968       yes
# 37         Advanced Radio Telecom   42.6  -60.1  ...    0.3    4.130       yes
# 38                    SSE Telecom   43.0  -49.2  ...  119.9    2.919       yes
# 39             SBC Communications   -7.2   18.6  ...   52.2    2.413        no
# 40            Time Warner Telecom    4.1  -10.1  ...   36.0    7.623        no
# 41                      IDT Corp.   48.7   38.4  ...   65.4    0.705        no
# 42          Ardent Communications  -28.8 -203.2  ...   14.7    0.111       yes
# 43          Exodus Communications   10.5  -12.4  ...   21.0    2.500       yes
# 44      Convergent Communications   26.1  -57.4  ...   54.2    0.855       yes
# 45                      Broadwing   -4.1   -5.8  ...   31.6    1.222        no
# 46                         Equant    8.2  -15.6  ...   87.7    5.444        no
# 47                  U.S. Wireless  -51.6 -326.1  ...    0.9    2.402       yes
# 48           Price Communications   16.1    3.6  ...   21.4    0.856        no
# 49               Openwave Systems   20.3  -61.3  ...   27.0   35.178        no
#
# [50 rows x 7 columns]

# %%
#Get data columns
columns = list(data.columns)

#create feature columns by removing target variable
# 'Company' column 
feature_cols = [x for x in columns if x not in ['Company', target_var]]
feature_cols
# Out:
# ['WC/TA', 'RE/TA', 'EBIT/TA', 'S/TA', 'BVE/BVL']

# %%
X = data[feature_cols] # Features
y = data[target_var] # Target variable

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1) # 80% training and 20% test
y_test
# Out:
# 27    yes
# 35    yes
# 40     no
# 38    yes
# 2      no
# 3      no
# 48     no
# 29     no
# 46     no
# 31    yes
# Name: Bankrupt, dtype: object

# %%
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)

y_pred
# Out:
# array(['no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'yes'],
#       dtype='<U3')

# %%
 print("Number of mislabeled points out of a total %d points : %d"
    % (X_test.shape[0],(y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 10 points : 2
